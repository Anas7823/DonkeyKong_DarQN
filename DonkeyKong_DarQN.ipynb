# %%
# !pip install gymnasium[atari] ale-py shimmy opencv-python tensorflow
# Out:
# Collecting ale-py
#   Downloading ale_py-0.11.2-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting opencv-python
#   Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Collecting tensorflow
#   Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl.metadata (4.6 kB)
# Collecting gymnasium[atari]
#   Downloading gymnasium-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium[atari])
#   Downloading numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium[atari])
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium[atari])
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium[atari])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting numpy>=1.21.0 (from gymnasium[atari])
#   Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.3.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\anase\documents\master_ii\deep learning avance\.venv\lib\site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting setuptools (from tensorflow)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: six>=1.12.0 in c:\users\anase\documents\master_ii\deep learning avance\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.2.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp312-cp312-win_amd64.whl.metadata (3.8 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting keras>=3.10.0 (from tensorflow)
#   Downloading keras-3.12.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting h5py>=3.11.0 (from tensorflow)
#   Using cached h5py-3.15.1-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Downloading ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl.metadata (9.2 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Downloading markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting pillow (from tensorboard~=2.20.0->tensorflow)
#   Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Downloading werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.10.0->tensorflow)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.10.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.10.0->tensorflow)
#   Downloading optree-0.18.0-cp312-cp312-win_amd64.whl.metadata (35 kB)
# Collecting markupsafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow)
#   Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.10.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anase\documents\master_ii\deep learning avance\.venv\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading gymnasium-1.2.2-py3-none-any.whl (952 kB)
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/952.1 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/952.1 kB ? eta -:--:--
#    ---------------------- ----------------- 524.3/952.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 524.3/952.1 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 952.1/952.1 kB 1.2 MB/s  0:00:00
# Downloading ale_py-0.11.2-cp312-cp312-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.5 MB ? eta -:--:--
#    --------- ------------------------------ 0.8/3.5 MB 2.0 MB/s eta 0:00:02
#    ------------ --------------------------- 1.0/3.5 MB 1.9 MB/s eta 0:00:02
#    ------------------ --------------------- 1.6/3.5 MB 2.0 MB/s eta 0:00:01
#    ------------------------ --------------- 2.1/3.5 MB 2.3 MB/s eta 0:00:01
#    ------------------------------ --------- 2.6/3.5 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 2.4 MB/s  0:00:01
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.0 MB 1.5 MB/s eta 0:00:26
#     --------------------------------------- 0.8/39.0 MB 1.6 MB/s eta 0:00:24
#    - -------------------------------------- 1.6/39.0 MB 2.5 MB/s eta 0:00:16
#    -- ------------------------------------- 2.4/39.0 MB 2.7 MB/s eta 0:00:14
#    --- ------------------------------------ 3.1/39.0 MB 2.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.5/39.0 MB 3.7 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.2/39.0 MB 3.8 MB/s eta 0:00:09
#    ------ --------------------------------- 6.0/39.0 MB 3.7 MB/s eta 0:00:10
#    ------ --------------------------------- 6.8/39.0 MB 3.8 MB/s eta 0:00:09
#    -------- ------------------------------- 8.1/39.0 MB 3.9 MB/s eta 0:00:08
#    --------- ------------------------------ 9.2/39.0 MB 4.0 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.2/39.0 MB 4.1 MB/s eta 0:00:07
#    ----------- ---------------------------- 11.5/39.0 MB 4.3 MB/s eta 0:00:07
#    ------------- -------------------------- 13.4/39.0 MB 4.7 MB/s eta 0:00:06
#    --------------- ------------------------ 15.5/39.0 MB 5.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 16.5/39.0 MB 5.2 MB/s eta 0:00:05
#    ------------------ --------------------- 18.4/39.0 MB 5.3 MB/s eta 0:00:04
#    -------------------- ------------------- 20.2/39.0 MB 5.4 MB/s eta 0:00:04
#    ----------------------- ---------------- 22.5/39.0 MB 5.8 MB/s eta 0:00:03
#    ------------------------- -------------- 24.4/39.0 MB 6.0 MB/s eta 0:00:03
#    -------------------------- ------------- 26.2/39.0 MB 6.2 MB/s eta 0:00:03
#    ----------------------------- ---------- 28.6/39.0 MB 6.4 MB/s eta 0:00:02
#    ------------------------------- -------- 30.4/39.0 MB 6.5 MB/s eta 0:00:02
#    --------------------------------- ------ 32.8/39.0 MB 6.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.9/39.0 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/39.0 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  38.5/39.0 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.0/39.0 MB 6.8 MB/s  0:00:05
# Using cached numpy-2.2.6-cp312-cp312-win_amd64.whl (12.6 MB)
# Using cached tensorflow-2.20.0-cp312-cp312-win_amd64.whl (331.9 MB)
# Downloading grpcio-1.76.0-cp312-cp312-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ------------- -------------------------- 1.6/4.7 MB 9.4 MB/s eta 0:00:01
#    -------------------- ------------------- 2.4/4.7 MB 9.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 3.4/4.7 MB 5.4 MB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 4.7 MB/s  0:00:00
# Downloading ml_dtypes-0.5.4-cp312-cp312-win_amd64.whl (212 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached h5py-3.15.1-cp312-cp312-win_amd64.whl (2.9 MB)
# Downloading keras-3.12.0-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 9.7 MB/s  0:00:00
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Downloading markdown-3.10-py3-none-any.whl (107 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading termcolor-3.2.0-py3-none-any.whl (7.7 kB)
# Downloading werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Using cached markupsafe-3.0.3-cp312-cp312-win_amd64.whl (15 kB)
# Downloading wrapt-2.0.1-cp312-cp312-win_amd64.whl (60 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.18.0-cp312-cp312-win_amd64.whl (312 kB)
# Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached rich-14.2.0-py3-none-any.whl (243 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, farama-notifications, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorboard-data-server, setuptools, protobuf, pillow, opt_einsum, numpy, mdurl, markupsafe, markdown, idna, google_pasta, gast, cloudpickle, charset_normalizer, certifi, absl-py, werkzeug, requests, optree, opencv-python, ml_dtypes, markdown-it-py, h5py, gymnasium, grpcio, astunparse, ale-py, tensorboard, shimmy, rich, keras, tensorflow
#
#     ---------------------------------------  1/41 [libclang]
#     ---------------------------------------  1/41 [libclang]
#     ---------------------------------------  1/41 [libclang]
#     ---------------------------------------  1/41 [libclang]
#    - --------------------------------------  2/41 [flatbuffers]
#    - --------------------------------------  2/41 [flatbuffers]
#    --- ------------------------------------  4/41 [wrapt]
#    --- ------------------------------------  4/41 [wrapt]
#    ---- -----------------------------------  5/41 [wheel]
#    ---- -----------------------------------  5/41 [wheel]
#    ---- -----------------------------------  5/41 [wheel]
#    ---- -----------------------------------  5/41 [wheel]
#    ---- -----------------------------------  5/41 [wheel]
#    ---- -----------------------------------  5/41 [wheel]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ----- ----------------------------------  6/41 [urllib3]
#    ------ ---------------------------------  7/41 [typing-extensions]
#    -------- -------------------------------  9/41 [tensorboard-data-server]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    --------- ------------------------------ 10/41 [setuptools]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ---------- ----------------------------- 11/41 [protobuf]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ----------- ---------------------------- 12/41 [pillow]
#    ------------ --------------------------- 13/41 [opt_einsum]
#    ------------ --------------------------- 13/41 [opt_einsum]
#    ------------ --------------------------- 13/41 [opt_einsum]
#    ------------ --------------------------- 13/41 [opt_einsum]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    ------------- -------------------------- 14/41 [numpy]
#    --------------- ------------------------ 16/41 [markupsafe]
#    ---------------- ----------------------- 17/41 [markdown]
#    ---------------- ----------------------- 17/41 [markdown]
#    ---------------- ----------------------- 17/41 [markdown]
#    ---------------- ----------------------- 17/41 [markdown]
#    ---------------- ----------------------- 17/41 [markdown]
#    ---------------- ----------------------- 17/41 [markdown]
#    ----------------- ---------------------- 18/41 [idna]
#    ----------------- ---------------------- 18/41 [idna]
#    ------------------ --------------------- 19/41 [google_pasta]
#    ------------------ --------------------- 19/41 [google_pasta]
#    ------------------ --------------------- 19/41 [google_pasta]
#    ------------------- -------------------- 20/41 [gast]
#    --------------------- ------------------ 22/41 [charset_normalizer]
#    --------------------- ------------------ 22/41 [charset_normalizer]
#    --------------------- ------------------ 22/41 [charset_normalizer]
#    ----------------------- ---------------- 24/41 [absl-py]
#    ----------------------- ---------------- 24/41 [absl-py]
#    ----------------------- ---------------- 24/41 [absl-py]
#    ----------------------- ---------------- 24/41 [absl-py]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------ --------------- 25/41 [werkzeug]
#    ------------------------- -------------- 26/41 [requests]
#    ------------------------- -------------- 26/41 [requests]
#    -------------------------- ------------- 27/41 [optree]
#    -------------------------- ------------- 27/41 [optree]
#    -------------------------- ------------- 27/41 [optree]
#    --------------------------- ------------ 28/41 [opencv-python]
#    --------------------------- ------------ 28/41 [opencv-python]
#    --------------------------- ------------ 28/41 [opencv-python]
#    --------------------------- ------------ 28/41 [opencv-python]
#    --------------------------- ------------ 28/41 [opencv-python]
#    --------------------------- ------------ 28/41 [opencv-python]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ----------------------------- ---------- 30/41 [markdown-it-py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------ --------- 31/41 [h5py]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    ------------------------------- -------- 32/41 [gymnasium]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    -------------------------------- ------- 33/41 [grpcio]
#    --------------------------------- ------ 34/41 [astunparse]
#    ---------------------------------- ----- 35/41 [ale-py]
#    ---------------------------------- ----- 35/41 [ale-py]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ----------------------------------- ---- 36/41 [tensorboard]
#    ------------------------------------ --- 37/41 [shimmy]
#    ------------------------------------ --- 37/41 [shimmy]
#    ------------------------------------ --- 37/41 [shimmy]
#    ------------------------------------ --- 37/41 [shimmy]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    ------------------------------------- -- 38/41 [rich]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    -------------------------------------- - 39/41 [keras]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
# ...
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------  40/41 [tensorflow]
#    ---------------------------------------- 41/41 [tensorflow]
#
# Successfully installed absl-py-2.3.1 ale-py-0.11.2 astunparse-1.6.3 certifi-2025.11.12 charset_normalizer-3.4.4 cloudpickle-3.1.2 farama-notifications-0.0.4 flatbuffers-25.9.23 gast-0.7.0 google_pasta-0.2.0 grpcio-1.76.0 gymnasium-1.2.2 h5py-3.15.1 idna-3.11 keras-3.12.0 libclang-18.1.1 markdown-3.10 markdown-it-py-4.0.0 markupsafe-3.0.3 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 numpy-2.2.6 opencv-python-4.12.0.88 opt_einsum-3.4.0 optree-0.18.0 pillow-12.0.0 protobuf-6.33.2 requests-2.32.5 rich-14.2.0 setuptools-80.9.0 shimmy-2.0.0 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.2.0 typing-extensions-4.15.0 urllib3-2.6.2 werkzeug-3.1.4 wheel-0.45.1 wrapt-2.0.1

# %%
import gymnasium as gym
import ale_py
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
import numpy as np
import cv2
from collections import deque
import random

# %%
# Enregistrement des environnements ALE
gym.register_envs(ale_py)

# --- 1. Configuration et Hyperparamètres ---
CONFIG = {
    'env_name': 'ALE/DonkeyKong-v5',
    'state_shape': (84, 84, 1), # (H, W, Channels) - Grayscale
    'seq_len': 4,               # Longueur de la séquence pour le LSTM
    'gamma': 0.99,
    'learning_rate': 0.0001,
    'epsilon_start': 1.0,
    'epsilon_min': 0.1,
    'epsilon_decay': 0.99995, # Decay plus lent pour laisser le temps d'apprendre
    'batch_size': 32,
    'memory_size': 20000,     # Taille du buffer
    'target_update_freq': 1000,
    'train_freq': 4
}

# %%
# --- 2. Wrappers pour l'environnement ---
# Ces wrappers transforment l'image brute (210,160,3) en (84,84,1) normalisé
class AtariPreprocessing(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0, shape=(84, 84, 1), dtype=np.float32)

    def step(self, action):
        obs, reward, terminated, truncated, info = self.env.step(action)
        return self._process(obs), reward, terminated, truncated, info

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return self._process(obs), info

    def _process(self, frame):
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY) # Gris
        frame = cv2.resize(frame, (84, 84))             # Resize
        frame = frame / 255.0                           # Normalisation 0-1
        return np.expand_dims(frame, axis=-1)           # Ajout dimension channel

def make_env():
    # render_mode='rgb_array' est nécessaire pour éviter des erreurs graphiques sur serveur
    env = gym.make(CONFIG['env_name'], render_mode='rgb_array')
    env = AtariPreprocessing(env)
    return env

# %%
# --- 3. Modèle DARQN (Dueling Attention Recurrent Q-Network) ---
class DuelingDARQN(models.Model):
    def __init__(self, action_size):
        super(DuelingDARQN, self).__init__()

        # CNN Encoder (TimeDistributed pour appliquer à chaque frame de la séquence)
        self.conv1 = layers.TimeDistributed(layers.Conv2D(32, 8, strides=4, activation='relu'))
        self.conv2 = layers.TimeDistributed(layers.Conv2D(64, 4, strides=2, activation='relu'))
        self.conv3 = layers.TimeDistributed(layers.Conv2D(64, 3, strides=1, activation='relu'))
        self.flatten = layers.TimeDistributed(layers.Flatten())

        # Recurrent Layer
        self.lstm = layers.LSTM(512, return_sequences=True)

        # Attention Mechanism (Multi-Head est plus robuste)
        self.attention = layers.MultiHeadAttention(num_heads=2, key_dim=64)
        self.layer_norm = layers.LayerNormalization()

        # Dueling Streams
        # 1. Value Stream (V)
        self.v_dense = layers.Dense(512, activation='relu')
        self.v_out = layers.Dense(1)

        # 2. Advantage Stream (A)
        self.a_dense = layers.Dense(512, activation='relu')
        self.a_out = layers.Dense(action_size)

    def call(self, inputs):
        # inputs shape: (Batch, Seq_Len, 84, 84, 1)
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)

        # LSTM Processing
        lstm_out = self.lstm(x) # (Batch, Seq, 512)

        # Self-Attention sur la dimension temporelle
        # L'attention permet de pondérer l'importance des frames passées
        attn_out = self.attention(query=lstm_out, value=lstm_out, key=lstm_out)
        context = self.layer_norm(lstm_out + attn_out)

        # On prend souvent le dernier état ou une moyenne pondérée.
        # Ici on prend le dernier état contextuel après attention.
        last_context = context[:, -1, :]

        # Dueling Logic
        v = self.v_dense(last_context)
        v = self.v_out(v)

        a = self.a_dense(last_context)
        a = self.a_out(a)

        # Q = V + (A - mean(A))
        q = v + (a - tf.reduce_mean(a, axis=1, keepdims=True))
        return q

# %%
# --- 4. Agent Double DQN ---
class Agent:
    def __init__(self, action_size):
        self.action_size = action_size
        self.epsilon = CONFIG['epsilon_start']

        # Création des modèles
        self.model = DuelingDARQN(action_size)
        self.target_model = DuelingDARQN(action_size)

        # Compilation dummy pour initialiser les poids (nécessaire pour copier vers target)
        dummy_input = tf.zeros((1, CONFIG['seq_len'], *CONFIG['state_shape']))
        self.model(dummy_input)
        self.target_model(dummy_input)
        self.update_target()

        self.optimizer = optimizers.Adam(learning_rate=CONFIG['learning_rate'], clipnorm=1.0)

        # Replay Buffer (Deque est plus simple pour commencer)
        self.memory = deque(maxlen=CONFIG['memory_size'])

    def update_target(self):
        self.target_model.set_weights(self.model.get_weights())

    def act(self, state_seq):
        if np.random.rand() < self.epsilon:
            return np.random.randint(self.action_size)

        # state_seq est (Seq, 84, 84, 1), on ajoute la dimension Batch -> (1, Seq, 84, 84, 1)
        state_tensor = tf.convert_to_tensor([state_seq], dtype=tf.float32)
        q_values = self.model(state_tensor)
        return np.argmax(q_values.numpy()[0])

    def remember(self, s, a, r, ns, d):
        self.memory.append((s, a, r, ns, d))

    def train(self):
        if len(self.memory) < CONFIG['batch_size']:
            return

        batch = random.sample(self.memory, CONFIG['batch_size'])

        # Conversion en numpy arrays
        states = np.array([i[0] for i in batch], dtype=np.float32)
        actions = np.array([i[1] for i in batch])
        rewards = np.array([i[2] for i in batch], dtype=np.float32)
        next_states = np.array([i[3] for i in batch], dtype=np.float32)
        dones = np.array([i[4] for i in batch], dtype=np.float32)

        # --- Double DQN Logic ---
        # 1. Utiliser le modèle principal pour choisir la meilleure action suivante
        next_q_main_model = self.model(next_states)
        best_next_actions = tf.argmax(next_q_main_model, axis=1)

        # 2. Utiliser le modèle cible pour calculer la valeur Q de cette action
        next_q_target_model = self.target_model(next_states)

        # Sélection des Q-values correspondant aux meilleures actions
        indices = tf.stack([tf.range(CONFIG['batch_size'], dtype=tf.int64), best_next_actions], axis=1)
        target_q_values = tf.gather_nd(next_q_target_model, indices)

        # 3. Calcul de la cible finale (Bellman equation)
        targets = rewards + (1 - dones) * CONFIG['gamma'] * target_q_values

        with tf.GradientTape() as tape:
            q_values = self.model(states)

            # On récupère Q(s, a) pour les actions jouées
            action_indices = tf.stack([tf.range(CONFIG['batch_size'], dtype=tf.int32), actions], axis=1)
            q_action = tf.gather_nd(q_values, action_indices)

            # Loss (Huber loss est souvent plus stable que MSE pour DQN)
            loss = tf.keras.losses.Huber()(targets, q_action)

        grads = tape.gradient(loss, self.model.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.model.trainable_variables))

        # Epsilon Decay
        if self.epsilon > CONFIG['epsilon_min']:
            self.epsilon *= CONFIG['epsilon_decay']

# %%
# --- 5. Boucle Principale ---
env = make_env()
action_size = env.action_space.n
agent = Agent(action_size)

scores = []
score_window = deque(maxlen=100)

print(f"Début de l'entraînement sur {CONFIG['env_name']}...")
print(f"Action Space: {action_size}")

for episode in range(5000): # Nombre d'épisodes
    # Reset environnement
    obs, info = env.reset()

    # Initialisation de la séquence (Remplir avec la première frame)
    # Shape: (Seq_Len, 84, 84, 1)
    state_seq = np.stack([obs] * CONFIG['seq_len'], axis=0)

    score = 0
    done = False
    step = 0

    while not done:
        # 1. Action
        # On aplatit la dim sequence pour le stockage propre si nécessaire, mais ici on garde (Seq, H, W, C)
        # Mais attention: le model attend (Seq, 84, 84, 1)
        # obs est (84, 84, 1)

        action = agent.act(state_seq)

        # 2. Step
        next_obs, reward, terminated, truncated, _ = env.step(action)
        done = terminated or truncated

        # Mise à jour de la séquence
        # On décale la séquence et on ajoute la nouvelle frame à la fin
        next_state_seq = np.roll(state_seq, -1, axis=0)
        next_state_seq[-1] = next_obs

        # 3. Stockage
        agent.remember(state_seq, action, reward, next_state_seq, done)

        state_seq = next_state_seq
        score += reward
        step += 1

        # 4. Entraînement
        if step % CONFIG['train_freq'] == 0:
            agent.train()

    # Fin d'épisode
    if episode % (CONFIG['target_update_freq'] // 100) == 0: # Update approximatif
        agent.update_target()

    score_window.append(score)
    avg_score = np.mean(score_window)

    print(f"Episode: {episode} | Score: {score:.1f} | Avg Score: {avg_score:.1f} | Epsilon: {agent.epsilon:.3f}")

    if avg_score >= 300: # Seuil arbitraire pour sauvegarder
        agent.model.save_weights("donkey_kong_darqn.h5")

env.close()
# Out:
# Début de l'entraînement sur ALE/DonkeyKong-v5...
# Action Space: 18
# Episode: 0 | Score: 100.0 | Avg Score: 100.0 | Epsilon: 0.992
# Episode: 1 | Score: 200.0 | Avg Score: 150.0 | Epsilon: 0.980
# Episode: 2 | Score: 300.0 | Avg Score: 200.0 | Epsilon: 0.970
# Episode: 3 | Score: 100.0 | Avg Score: 175.0 | Epsilon: 0.961
# Episode: 4 | Score: 100.0 | Avg Score: 160.0 | Epsilon: 0.952
# Episode: 5 | Score: 200.0 | Avg Score: 166.7 | Epsilon: 0.945
# Episode: 6 | Score: 200.0 | Avg Score: 171.4 | Epsilon: 0.937
# Episode: 7 | Score: 200.0 | Avg Score: 175.0 | Epsilon: 0.928
# Episode: 8 | Score: 100.0 | Avg Score: 166.7 | Epsilon: 0.920
# Episode: 9 | Score: 200.0 | Avg Score: 170.0 | Epsilon: 0.912
# Episode: 10 | Score: 200.0 | Avg Score: 172.7 | Epsilon: 0.904
# Episode: 11 | Score: 100.0 | Avg Score: 166.7 | Epsilon: 0.896
# Episode: 12 | Score: 300.0 | Avg Score: 176.9 | Epsilon: 0.886
# Episode: 13 | Score: 100.0 | Avg Score: 171.4 | Epsilon: 0.880
# Episode: 14 | Score: 100.0 | Avg Score: 166.7 | Epsilon: 0.872
# Episode: 15 | Score: 200.0 | Avg Score: 168.8 | Epsilon: 0.863
# Episode: 16 | Score: 100.0 | Avg Score: 164.7 | Epsilon: 0.853
# Episode: 17 | Score: 100.0 | Avg Score: 161.1 | Epsilon: 0.845
# Episode: 18 | Score: 0.0 | Avg Score: 152.6 | Epsilon: 0.837
# Episode: 19 | Score: 100.0 | Avg Score: 150.0 | Epsilon: 0.830
# Episode: 20 | Score: 300.0 | Avg Score: 157.1 | Epsilon: 0.822
# Episode: 21 | Score: 200.0 | Avg Score: 159.1 | Epsilon: 0.814
# Episode: 22 | Score: 200.0 | Avg Score: 160.9 | Epsilon: 0.807
# Episode: 23 | Score: 300.0 | Avg Score: 166.7 | Epsilon: 0.800
# Episode: 24 | Score: 0.0 | Avg Score: 160.0 | Epsilon: 0.794
# Episode: 25 | Score: 200.0 | Avg Score: 161.5 | Epsilon: 0.786
# Episode: 26 | Score: 100.0 | Avg Score: 159.3 | Epsilon: 0.779
# Episode: 27 | Score: 300.0 | Avg Score: 164.3 | Epsilon: 0.773
# Episode: 28 | Score: 0.0 | Avg Score: 158.6 | Epsilon: 0.766
# Episode: 29 | Score: 0.0 | Avg Score: 153.3 | Epsilon: 0.759
# Episode: 30 | Score: 100.0 | Avg Score: 151.6 | Epsilon: 0.753
# Episode: 31 | Score: 0.0 | Avg Score: 146.9 | Epsilon: 0.746
# Episode: 32 | Score: 300.0 | Avg Score: 151.5 | Epsilon: 0.739
# Episode: 33 | Score: 100.0 | Avg Score: 150.0 | Epsilon: 0.732
# Episode: 34 | Score: 300.0 | Avg Score: 154.3 | Epsilon: 0.725
# Episode: 35 | Score: 0.0 | Avg Score: 150.0 | Epsilon: 0.718
# Episode: 36 | Score: 100.0 | Avg Score: 148.6 | Epsilon: 0.712
# Episode: 37 | Score: 0.0 | Avg Score: 144.7 | Epsilon: 0.706
# Episode: 38 | Score: 200.0 | Avg Score: 146.2 | Epsilon: 0.699
# Episode: 39 | Score: 300.0 | Avg Score: 150.0 | Epsilon: 0.689
# Episode: 40 | Score: 200.0 | Avg Score: 151.2 | Epsilon: 0.684
# Episode: 41 | Score: 0.0 | Avg Score: 147.6 | Epsilon: 0.678
# Episode: 42 | Score: 100.0 | Avg Score: 146.5 | Epsilon: 0.671
# Episode: 43 | Score: 100.0 | Avg Score: 145.5 | Epsilon: 0.665
# Episode: 44 | Score: 200.0 | Avg Score: 146.7 | Epsilon: 0.659
# Episode: 45 | Score: 0.0 | Avg Score: 143.5 | Epsilon: 0.653
# Episode: 46 | Score: 200.0 | Avg Score: 144.7 | Epsilon: 0.646
# Episode: 47 | Score: 100.0 | Avg Score: 143.8 | Epsilon: 0.641
# Episode: 48 | Score: 200.0 | Avg Score: 144.9 | Epsilon: 0.635
# Episode: 49 | Score: 100.0 | Avg Score: 144.0 | Epsilon: 0.630
# Episode: 50 | Score: 0.0 | Avg Score: 141.2 | Epsilon: 0.625
# Episode: 51 | Score: 200.0 | Avg Score: 142.3 | Epsilon: 0.620
# Episode: 52 | Score: 400.0 | Avg Score: 147.2 | Epsilon: 0.614
# Episode: 53 | Score: 100.0 | Avg Score: 146.3 | Epsilon: 0.607
# Episode: 54 | Score: 100.0 | Avg Score: 145.5 | Epsilon: 0.602
# Episode: 55 | Score: 300.0 | Avg Score: 148.2 | Epsilon: 0.595
# Episode: 56 | Score: 0.0 | Avg Score: 145.6 | Epsilon: 0.590
# Episode: 57 | Score: 100.0 | Avg Score: 144.8 | Epsilon: 0.585
# Episode: 58 | Score: 0.0 | Avg Score: 142.4 | Epsilon: 0.580
# Episode: 59 | Score: 200.0 | Avg Score: 143.3 | Epsilon: 0.575
# Episode: 60 | Score: 300.0 | Avg Score: 145.9 | Epsilon: 0.569
# Episode: 61 | Score: 200.0 | Avg Score: 146.8 | Epsilon: 0.562
# Episode: 62 | Score: 200.0 | Avg Score: 147.6 | Epsilon: 0.557
# Episode: 63 | Score: 200.0 | Avg Score: 148.4 | Epsilon: 0.552
# Episode: 64 | Score: 100.0 | Avg Score: 147.7 | Epsilon: 0.547
# Episode: 65 | Score: 100.0 | Avg Score: 147.0 | Epsilon: 0.542
# Episode: 66 | Score: 100.0 | Avg Score: 146.3 | Epsilon: 0.536
# Episode: 67 | Score: 0.0 | Avg Score: 144.1 | Epsilon: 0.529
# Episode: 68 | Score: 100.0 | Avg Score: 143.5 | Epsilon: 0.523
# Episode: 69 | Score: 100.0 | Avg Score: 142.9 | Epsilon: 0.519
# Episode: 70 | Score: 100.0 | Avg Score: 142.3 | Epsilon: 0.514
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10424\3840043717.py in ?()
#      26         # On aplatit la dim sequence pour le stockage propre si nécessaire, mais ici on garde (Seq, H, W, C)
#      27         # Mais attention: le model attend (Seq, 84, 84, 1)
#      28         # obs est (84, 84, 1)
#      29
# ---> 30         action = agent.act(state_seq)
#      31
#      32         # 2. Step
#      33         next_obs, reward, terminated, truncated, _ = env.step(action)
#
# ~\AppData\Local\Temp\ipykernel_10424\2727360228.py in ?(self, state_seq)
#      27             return np.random.randint(self.action_size)
#      28
#      29         # state_seq est (Seq, 84, 84, 1), on ajoute la dimension Batch -> (1, Seq, 84, 84, 1)
#      30         state_tensor = tf.convert_to_tensor([state_seq], dtype=tf.float32)
# ---> 31         q_values = self.model(state_tensor)
#      32         return np.argmax(q_values.numpy()[0])
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# ~\AppData\Local\Temp\ipykernel_10424\3710937238.py in ?(self, inputs)
#      51         a = self.a_dense(last_context)
#      52         a = self.a_out(a)
#      53
#      54         # Q = V + (A - mean(A))
# ---> 55         q = v + (a - tf.reduce_mean(a, axis=1, keepdims=True))
#      56         return q
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py in ?(*args, **kwargs)
#      86   def wrapper(*args, **kwargs):
#      87     if not ops.is_auto_dtype_conversion_enabled():
# ---> 88       return op(*args, **kwargs)
#      89     bound_arguments = signature.bind(*args, **kwargs)
#      90     bound_arguments.apply_defaults()
#      91     bound_kwargs = bound_arguments.arguments
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1261
#    1262       # Fallback dispatch system (dispatch v1):
#    1263       try:
#    1264         return dispatch_target(*args, **kwargs)
# -> 1265       except (TypeError, ValueError):
#    1266         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267         # TypeError, when given unexpected types.  So we need to catch both.
#    1268         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\tensorflow\python\ops\math_ops.py in ?(input_tensor, axis, keepdims, name)
#    2590   """
#    2591   keepdims = False if keepdims is None else bool(keepdims)
#    2592   return _may_reduce_to_scalar(
#    2593       keepdims, axis,
# -> 2594       gen_math_ops.mean(
#    2595           input_tensor, _ReductionDims(input_tensor, axis), keepdims,
#    2596           name=name))
#
# c:\Users\anase\Documents\Master_II\Deep Learning avance\.venv\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py in ?(input, axis, keep_dims, name)
#    6510         _ctx, "Mean", name, input, axis, "keep_dims", keep_dims)
#    6511       return _result
#    6512     except _core._NotOkStatusException as e:
#    6513       _ops.raise_from_not_ok_status(e, name)
# -> 6514     except _core._FallbackException:
#    6515       pass
#    6516     try:
#    6517       return mean_eager_fallback(
#
# KeyboardInterrupt:

# %%
from google.colab import files

# 1. Sauvegarder les poids
# On utilise save_weights car sauvegarder un modèle "subclassé" (custom) entier est souvent buggé
agent.model.save_weights("donkey_kong_final.weights.h5")
print("Modèle sauvegardé localement dans le runtime Colab.")

# 2. Télécharger le fichier sur ton PC
files.download("donkey_kong_final.weights.h5")
